# %% [markdown]
# <a href="https://colab.research.google.com/github/arellanoej/ACTIVITY01/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import pandas as pd

# %%
import pandas as np

# %%
Jimdf=pd.read_csv ("https://raw.githubusercontent.com/arellanoej/ACTIVITY01/main/games.csv")

# %%
df.head()
# Out:
#       Away_Team   Home_Team        Date        Ref_Crew  Accepted_Count  \
# 0     Tennessee  Pittsburgh  09/10/2009      Bill Leavy              11
# 1         Miami     Atlanta  09/13/2009    Walt Coleman               8
# 2   Kansas City   Baltimore  09/13/2009  Gene Steratore              11
# 3  Philadelphia    Carolina  09/13/2009  Jeff Triplette              14
# 4        Denver  Cincinnati  09/13/2009    Jerome Boger              10
#
#    Yards  Away_Count  Away_Yards  Home_Count  Home_Yards  Total_Flags  Week  \
# 0     88           5          28           6          60           13     1
# 1     62           4          27           4          35           11     1
# 2     80           3          15           8          65           14     1
# 3    106           9          76           5          30           14     1
# 4     66           6          39           4          27           12     1
#
#    Year
# 0  2009
# 1  2009
# 2  2009
# 3  2009
# 4  2009

# %%
WeData=df [['Total_Flags','Week']] . values

# %%
# Visualize the original dataset
plt.scatter(Data[:, 0], Data[:, 1], s=50, cmap='viridis')
plt.title("Original Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()
# Out:
# <ipython-input-63-1be0c3cd29da>:2: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(Data[:, 0], Data[:, 1], s=50, cmap='viridis')

# %%
# Apply K-means clustering with K=3
kmeans = KMeans(n_clusters=3, random_state=42)
predicted_labels = kmeans.fit_predict(Data)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
df = df.set_index('Date')
df.index = pd.to_datetime(df.index)

# %%
#create a col flot
def create_features(df):
    df = df.copy()
    df['hour'] = df.index.hour
    df['dayofweek'] = df.index.day_of_week
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['dayofyear'] = df.index.dayofyear
    return df

df = create_features(df)

# %%
# Visualize the initial clustering result
plt.scatter(Data[:, 0], Data[:, 1], c=predicted_labels, s=50, cmap='viridis')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')
plt.title("Initial Clustering Result")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.show()

# %%
# Assuming your dataset has two features, you can modify this accordingly
Data = df[['month', 'quarter', 'dayofyear']].values

# %%
# Iterative process - Iteration 2
for iteration in range(2):  # Repeat for a few iterations (you can adjust this number)
    # Step 3: Reassign Data Points
    predicted_labels = kmeans.predict(Data)

    # Step 4: Update Centroids
    kmeans.cluster_centers_ = np.array([Data[predicted_labels == i].mean(axis=0) for i in range(kmeans.n_clusters)])

    # Visualization
    plt.scatter(Data[:, 0], Data[:, 1], c=predicted_labels, s=50, cmap='viridis')
    plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')
    plt.title(f"Iteration {iteration + 1}")
    plt.xlabel("Feature 1")
    plt.ylabel("Feature 2")
    plt.legend()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-084278c34ccd> in <cell line: 2>()
#       2 for iteration in range(2):  # Repeat for a few iterations (you can adjust this number)
#       3     # Step 3: Reassign Data Points
# ----> 4     predicted_labels = kmeans.predict(Data)
#       5
#       6     # Step 4: Update Centroids
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py in predict(self, X, sample_weight)
#    1059         sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
#    1060
# -> 1061         labels = _labels_inertia_threadpool_limit(
#    1062             X,
#    1063             sample_weight,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py in _labels_inertia_threadpool_limit(X, sample_weight, centers, n_threads, return_inertia)
#     811     """Same as _labels_inertia but in a threadpool_limits context."""
#     812     with threadpool_limits(limits=1, user_api="blas"):
# --> 813         result = _labels_inertia(X, sample_weight, centers, n_threads, return_inertia)
#     814
#     815     return result
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py in _labels_inertia(X, sample_weight, centers, n_threads, return_inertia)
#     776
#     777     labels = np.full(n_samples, -1, dtype=np.int32)
# --> 778     center_shift = np.zeros(n_clusters, dtype=centers.dtype)
#     779
#     780     if sp.issparse(X):
#
# TypeError: Cannot interpret 'PandasDtype('object')' as a data type
